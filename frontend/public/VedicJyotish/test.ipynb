# %%
for i in range(30):
    print(
        f"public/assets/icon/moon/moon{i}.png",
        f"public/assets/icon/moon/moon_{i+1}.png",
    )
# Out:
# public/assets/icon/moon/moon0.png public/assets/icon/moon/moon_1.png
# public/assets/icon/moon/moon1.png public/assets/icon/moon/moon_2.png
# public/assets/icon/moon/moon2.png public/assets/icon/moon/moon_3.png
# public/assets/icon/moon/moon3.png public/assets/icon/moon/moon_4.png
# public/assets/icon/moon/moon4.png public/assets/icon/moon/moon_5.png
# public/assets/icon/moon/moon5.png public/assets/icon/moon/moon_6.png
# public/assets/icon/moon/moon6.png public/assets/icon/moon/moon_7.png
# public/assets/icon/moon/moon7.png public/assets/icon/moon/moon_8.png
# public/assets/icon/moon/moon8.png public/assets/icon/moon/moon_9.png
# public/assets/icon/moon/moon9.png public/assets/icon/moon/moon_10.png
# public/assets/icon/moon/moon10.png public/assets/icon/moon/moon_11.png
# public/assets/icon/moon/moon11.png public/assets/icon/moon/moon_12.png
# public/assets/icon/moon/moon12.png public/assets/icon/moon/moon_13.png
# ...
